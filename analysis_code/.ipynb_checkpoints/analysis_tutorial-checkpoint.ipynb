# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ls
# Out:
# Untitled.ipynb  worm13/

# %%
cd worm13/
# Out:
# /home/tushara/Documents/projects/phylab/elegans/worm13

# %%
ls
# Out:
# __MACOSX/  worm13/

# %%
cd worm13/
# Out:
# /home/tushara/Documents/projects/phylab/elegans/worm13/worm13

# %%
ls
# Out:
# MA2_0145.JPG*  MA2_0148.JPG*  MA2_0151.JPG*  MA2_0154.JPG*  MA2_0157.JPG*
# MA2_0146.JPG*  MA2_0149.JPG*  MA2_0152.JPG*  MA2_0155.JPG*
# MA2_0147.JPG*  MA2_0150.JPG*  MA2_0153.JPG*  MA2_0156.JPG*

# %%
img = plt.imread('MA2_0145.JPG')
plt.imshow(img)
plt.hist(img.ravel(), bins = 256)
plt.show()

# %%
img_r = img[:,:,0]
plt.imshow(img_r)
plt.show()

# %%
img_g = img[:,:,1]
plt.imshow(img_g, cmap = 'hot')
plt.show()

# %%
img_r = img[:,:,0]
plt.imshow(img_r)
plt.show()

plt.hist(img_r.ravel(), bins = 256)
plt.show()

t = 170
img_r = img_r > t
plt.imshow(img_r)
plt.show()

# %%
t = 170
img_r = img_r[1000:2000,2000:3500]
img_r = img_r < t
plt.imshow(img_r)
plt.show()
